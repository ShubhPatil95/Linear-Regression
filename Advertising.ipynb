# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('C://Users//hp//Desktop//Coding//Linear Regression//advertising.csv')
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
data.shape
# Out:
# (200, 4)

# %%
import seaborn as sb
sb.pairplot(data,x_vars=["TV","Radio","Newspaper"],y_vars=["Sales"],height=7,aspect=.7)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data[["TV","Radio","Newspaper"]] , data["Sales"], test_size=.20, random_state=42)

# %%
reg=linear_model.LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
yp=reg.predict(X_test)
yp=np.around(yp)
df1=pd.DataFrame({"Original":y_test,"Predicted":yp})
df1.head()
# Out:
#      Original  Predicted
# 95       16.9       16.0
# 15       22.4       21.0
# 30       21.4       22.0
# 158       7.3       11.0
# 128      24.7       22.0

# %%
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
print("Mean Sqaured Error: ",mean_squared_error(y_test,yp))
print("Mean Absolute Error:",mean_absolute_error(y_test,yp))
print("R Sqaure:",r2_score(y_test,yp))
# Out:
# Mean Sqaured Error:  3.2762499999999997
# Mean Absolute Error: 1.4825000000000002
# R Sqaure: 0.8962016167756562
